# %% [markdown]
# <a href="https://colab.research.google.com/github/albr8407-cloud/Probabilidad-y-Estadistica/blob/main/UNIDAD1/PROU1_Practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# # Unidad 1
# # Practica 4. Diagramas de Cajas y bigotes.
# # Docente: Dr.Jose Gabriel Rodriguez Rivas
# # Alumno: Bryan Arellano Perdue

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
    numero_aleatorio = round( random.uniform(50, 100), 2 )
    fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [58.76, 85.23, 75.89, 66.88, 85.88, 74.13, 76.56, 58.35, 95.08, 69.1, 85.29, 86.17, 78.26, 62.92, 91.08, 83.88, 53.79, 86.25, 67.33, 83.82, 73.41, 56.87, 77.07, 63.14, 67.22, 83.81, 77.64, 53.68, 72.52, 76.99, 74.68, 66.45, 65.71, 81.67, 66.74, 86.92, 74.75, 96.2, 51.5, 83.45, 87.3, 71.31, 68.98, 80.61, 92.85, 92.84, 56.34, 93.71, 95.63, 71.64, 64.85, 65.03, 61.15, 52.25, 62.5, 91.6, 51.57, 80.18, 89.4, 55.6, 69.49, 80.93, 60.42, 97.1, 78.36, 86.38, 59.59, 56.85, 91.9, 50.01, 55.22, 79.26, 89.78, 50.44, 95.78, 82.52, 93.75, 93.64, 95.39, 76.28, 88.97, 75.2, 61.77, 86.58, 71.8, 89.31, 76.19, 88.7, 99.93, 97.52, 91.45, 77.67, 92.33, 71.18, 54.43, 51.06, 72.37, 89.93, 66.14, 89.19]

# %%
fabrica2 = []
for i in range(100):
    numero_aleatorio = round( random.uniform(40, 93), 2 )
    fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [59.19, 57.34, 56.92, 44.54, 92.01, 43.93, 52.87, 43.97, 73.66, 50.84, 71.12, 40.58, 47.9, 69.57, 76.91, 59.58, 47.25, 90.76, 57.52, 57.91, 66.34, 53.16, 57.14, 84.74, 60.81, 56.19, 83.36, 63.25, 82.8, 69.13, 54.16, 47.21, 58.98, 42.14, 40.15, 52.88, 43.97, 45.75, 47.15, 64.4, 69.31, 82.08, 85.38, 50.03, 71.52, 74.82, 62.4, 53.87, 51.91, 76.23, 91.9, 55.41, 72.58, 76.82, 84.13, 60.72, 43.52, 66.92, 83.8, 89.68, 50.76, 50.95, 73.1, 47.77, 40.73, 62.67, 70.14, 88.3, 42.88, 75.59, 69.9, 71.43, 64.44, 65.69, 92.86, 47.41, 60.61, 76.12, 76.08, 57.2, 56.2, 54.22, 78.02, 91.66, 63.74, 66.77, 84.1, 51.69, 49.02, 91.4, 64.38, 61.11, 68.79, 43.49, 73.56, 41.8, 63.32, 81.84, 73.27, 64.0]

# %%
plt.boxplot(fabrica1)
plt.ylabel('Produccion en mts')
plt.title('Produccion de la fabrica 1')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(fabrica1,
                     vert=True,  #Alineacion Vertical
                     patch_artist=True) #Rellenar con color
ax1.set_title('Produccion fabrica 1')

bplot2 = ax2.boxplot(fabrica2,
                     vert=True,  #Alineacion Vertical
                     patch_artist=True) #Rellenar con color
ax2.set_title('Produccion fabrica 2')
plt.show()

# %%
# Insertamos un valor de 150 a la fabrica 1,
# Seria un valor atipico
fabrica1.append(150)
print(fabrica1)
# Out:
# [81.39, 66.58, 58.29, 79.96, 73.46, 74.09, 90.23, 97.78, 85.39, 56.32, 76.76, 64.76, 64.63, 86.12, 87.66, 92.56, 75.89, 56.85, 65.71, 59.32, 72.64, 95.39, 68.99, 67.19, 98.65, 57.97, 54.61, 83.69, 84.71, 70.54, 79.49, 99.36, 70.58, 61.24, 92.52, 65.68, 86.99, 60.31, 83.26, 78.38, 89.1, 68.46, 96.36, 86.71, 88.06, 98.57, 89.27, 88.5, 78.38, 73.08, 96.24, 51.97, 64.29, 84.89, 66.71, 79.45, 83.94, 77.73, 78.14, 51.75, 56.53, 78.14, 58.88, 98.8, 98.29, 88.36, 60.6, 83.26, 54.86, 66.69, 79.81, 59.17, 97.94, 68.29, 70.6, 74.57, 98.2, 52.4, 62.9, 66.12, 58.68, 58.96, 66.89, 81.66, 58.86, 90.8, 93.69, 81.29, 50.19, 61.63, 65.45, 50.14, 85.64, 52.49, 75.8, 83.24, 87.75, 67.82, 62.78, 54.41, 150]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(fabrica1,
                     vert=True,  # vertical box alignment
                     patch_artist=True) # fill with color
ax1.set_title('Produccion fabrica 1')

bplot2 = ax2.boxplot(fabrica2,
                     vert=True,  # vertical box aligment
                     patch_artist=True) # fill with color
ax2.set_title('Produccion fabrica 2')
plt.show()

# %%
# Agregamos ax1.set_ylim(0, 160) para garantizar que ambos graficos usen la
# misma escala vertical, facilitando la comparacion visual.

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 5))
bplot1 = ax1.boxplot(fabrica1,
                     vert=True, # Alinecion Vertical t
                     patch_artist=True) # Rellenar con color
ax1.set_title('Produccion fabrica 1')
ax1.set_ylim(30, 160) # Escala Uniforme de 0 a 160

bplot2 = ax2.boxplot(fabrica2,
                     vert=True, # Alinecion Vertical t
                     patch_artist=True) # Rellenar con color
ax2.set_title('Produccion fabrica 2')
ax2.set_ylim(30, 160) # Escala Uniforme de 0 a 160
plt.show()
