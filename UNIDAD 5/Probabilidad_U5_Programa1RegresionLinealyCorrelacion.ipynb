# %% [markdown]
# <a href="https://colab.research.google.com/github/albr8407-cloud/Probabilidad-y-Estadistica/blob/main/UNIDAD%205/Probabilidad_U5_Programa1RegresionLinealyCorrelacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Probabilidad y Estadistica
# ## Unidad 5
# ## Nombre: Bryan Arellano Perdue
# ## Facilitador: Jose Gabriel Rodriguez Rivas
# ## Programa 1: Regresion lineal y Correlacion.

# %%
from sklearn.linear_model import LinearRegression #Modelo de regresion lineal
import numpy as np

#Datos de entrada
periodos = [ 2018, 2019, 2020, 2021, 2022, 2023 ]
inversion = np.array([2, 3, 5, 4, 11, 5] ).reshape(-1, 1)
ganancias = [20, 25, 34, 30, 40, 31]

# Crear y entrenar el modelo de regresion lineal
modelo = LinearRegression()
modelo.fit(inversion, ganancias)

# Predecir la ganancia para el año 2024
ganacia_2024 = modelo.predict( [[8]] )

print("La ganancia esperada para el año es de:", ganacia_2024[0])

# Coeficientes de la regresion
print("Coeficientes de la pendiente (m):", modelo.coef_[0])
print("Intercepcion de la recta (b):", modelo.intercept_)
# Out:
# La ganancia esperada para el año es de: 36.0
# Coeficientes de la pendiente (m): 2.0000000000000004
# Intercepcion de la recta (b): 20.0
