# %% [markdown]
# <a href="https://colab.research.google.com/github/albr8407-cloud/Probabilidad-y-Estadistica/blob/main/UNIDAD%205/Probabilidad_U5_Programa3RegresionLinealyCorrelacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Probabilidad y Estadistica
# ## Unidad 5
# ## Alumno: Bryan Arellano Perdue.
# ## Facilitador: Jose Gabriel Rodriguez Rivas
# ## Programa 3: Regresion lineal y correlacion

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Definir tamaño
plt.figure(figsize=(6, 4))

# Datos de entrada
inversion = [2, 3, 5, 4, 11, 5]
ganancias = [20, 25, 34, 30, 40, 31]

# Crear el diagrama de dispersión con línea de regresión
sns.set(style="whitegrid")
sns.regplot(x=inversion, y=ganancias, scatter=True, color='blue')
plt.title('Diagrama de Dispersión con Línea de Regresión')
plt.xlabel('Inversión (millones)')
plt.ylabel('Ganancias (millones)')
plt.grid(True)
plt.show()
