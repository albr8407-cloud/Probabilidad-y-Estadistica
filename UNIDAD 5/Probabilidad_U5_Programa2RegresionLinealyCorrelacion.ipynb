# %% [markdown]
# <a href="https://colab.research.google.com/github/albr8407-cloud/Probabilidad-y-Estadistica/blob/main/UNIDAD%205/Probabilidad_U5_Programa2RegresionLinealyCorrelacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Probabilidad y Estadistica
# ## Unidad 5
# ## Alumno: Bryan Arellano Perdue.
# ## Facilitador: Jose Gabriel Rodriguez Rivas
# ## Programa 2: Regresion lineal y correlacion

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Definir tamaño de la figutra
plt.figure(figsize=(6, 4))

# Datos de entrada
inversion = [2, 3, 5, 4, 11, 5]
ganancias = [20, 25, 34, 30, 40, 31]

# Dibujar el diagrama de dispersion
sns.scatterplot(x = inversion, y = ganancias)
plt.title('Diagrama de Dispersion de Inversion vs. Ganancias')
plt.xlabel('Inversion (millones)')
plt.ylabel('Ganancias (millones)')
plt.grid(True)
plt.show()
